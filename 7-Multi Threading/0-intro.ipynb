# %% [markdown]
# # process
# به هر برنامه که بصورت مستقل در حال اجراست مثل
#  : کروم،پلیر،چایچارم،بازی
#
# # THREAD
# به کوچکترین واحدهای اجرای در هر  پروسس می گویم مثلا
#  +   در کروم هم میتوان همزمان موسیقی گوش داد
#  +   دانلود کرد
#  +   فیلم دید
#  +   وب گردی کرد
#
#  مجموعه این  ترد ها پروسس را می سازند
#  کلبیت اجرای هر پروسس نیز یک ترد هست.

# %% [markdown]
# در اجرای هر پروسس دو مورد پایین در گیر هستند
#
# + #### I/O wating  =  input/output
# + #### CPU processing

# %% [markdown]
# #### I/O banding
#
#  در این حالت سیپیو پردازشش را انجام داده انرا به خروجی/وروی می فرستد و منتظر گرفتن جواب می ماند در واقع برنامه معطل ورودی/خروجی است لذا به ان
#  (ای/او بندینگ)
#  در این حالت ما میتوانیم تا زمانی که سیپیو منتظر جواب است یک پردازش دیگر به سی پیو بدهبم در واقع در این حالت سی پیو همزمان دو کار انجام نمیدهد!!! بلکه در زمان اتظار یک تسک دیگر نیز انجام میدهد
#
# ##### به این حالت مالتی تردینگ میگویند
